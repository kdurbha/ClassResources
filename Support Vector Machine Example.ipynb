# %%
# importing required libraries numpy, pandas and matplotlib
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 

# importing scikit learn with make_blobs 
import sklearn
from sklearn.datasets.samples_generator import make_blobs 
  
# creating datasets X containing n_samples 
# Y containing two classes 
X, Y = make_blobs(n_samples=500, centers=2, 
                  random_state=0, cluster_std=0.40) 
  
# plotting scatters  
plt.scatter(X[:, 0], X[:, 1], c=Y, s=50, cmap='spring'); 
plt.show()

# %%
# creating line space between -1 to 3.5  
import numpy as np
xfit = np.linspace(-1, 3.5) 
  
# plotting scatter 
plt.scatter(X[:, 0], X[:, 1], c=Y, s=50, cmap='spring') 
  
# plot a line between the different sets of data 
for m, b, d in [(1, 0.65, 0.33), (0.5, 1.6, 0.55), (-0.2, 2.9, 0.2)]: 
    yfit = m * xfit + b 
    plt.plot(xfit, yfit, '-k') 
    plt.fill_between(xfit, yfit - d, yfit + d, edgecolor='none',  
    color='#AAAAAA', alpha=0.4) 
  
plt.xlim(-1, 3.5); 
plt.show()

# %%
# reading csv file and extracting class column to y. 
x = pd.read_csv("/Users/durbht1/Desktop/NMIMS/Datasets/Kaggle/Breast_cancer_data.csv") 
a = np.array(x)
print (a)
y  = a[:,30] # classes having 0 and 1

# extracting two features 
x = np.column_stack((x.malignant,x.benign)) 
x.shape # 569 samples and 2 features 
  
print (x),(y)
# Out:
# [[1.799e+01 1.038e+01 1.228e+02 1.001e+03 1.184e-01 0.000e+00]
#  [2.057e+01 1.777e+01 1.329e+02 1.326e+03 8.474e-02 0.000e+00]
#  [1.969e+01 2.125e+01 1.300e+02 1.203e+03 1.096e-01 0.000e+00]
#  ...
#  [1.660e+01 2.808e+01 1.083e+02 8.581e+02 8.455e-02 0.000e+00]
#  [2.060e+01 2.933e+01 1.401e+02 1.265e+03 1.178e-01 0.000e+00]
#  [7.760e+00 2.454e+01 4.792e+01 1.810e+02 5.263e-02 1.000e+00]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-00e59dc11159> in <module>
#       3 a = np.array(x)
#       4 print (a)
# ----> 5 y  = a[:,30] # classes having 0 and 1
#       6 print (y)
#
# IndexError: index 30 is out of bounds for axis 1 with size 6

# %%
# import support vector classifier 
from sklearn.svm import SVC # "Support Vector Classifier" 
clf = SVC(kernel='linear')

# fitting x samples and y classes 
clf.fit(x, y)
clf.predict([[120, 990]])
clf.predict([[85, 550]])
